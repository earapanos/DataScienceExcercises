# %% [markdown]
# # Árvores II - Tarefa I

# %% [markdown]
# ![image.png](attachment:f65bd82d-aa56-4cf2-8030-bb758771f332.png)
# [fonte](https://momentum.org/programs-services/manage-your-money/savings-app/pxfuel-creative-commons-zero-cc0-iphone-smartphone-cell-phone-mobile-technology-texting/)
#
# Neste exercício vamos trabalhar com a base de dados de identificação de atividade humana com smartphones. Smartphones possuem acelerômetro e giroscópio, que registram dados de aceleração e giro nos eixos X, Y e Z, com frequencia de 50 Hz (ou seja, 50 registros por segundo). Os dados foram agrupados a medidas de 0.3 Hz, calculando-se variáveis derivadas como aceleração mínima, máxima, média etc por eixo no período agrupado de tempo, resultando em 561 variáveis que podem ser lidas nas bases disponíveis.
#
# A base é oriunda de um experimento, em que os indivíduos realizavam uma de seis atividades corriqueiras:
# - andando
# - subindo escada
# - descendo escada
# - parado
# - sentado
# - deitado
#
# O objetivo é classificar a atividade humana com base nos dados do acelerômetro e giroscópio do celular.

# %% [markdown]
# ## 1. Carregar a base
#
# Sua primeira atividade é carregar a base.
#
# Ela está disponível neste link:
# https://archive.ics.uci.edu/ml/datasets/human+activity+recognition+using+smartphones
#
# dados https://archive.ics.uci.edu/ml/machine-learning-databases/00240/
# dataset.names https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.names
# UCI HAR Dataset.zip https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
#
# Você vai encontrar os seguintes arquivos:
#
# - **features.txt:** contém a lista com os nomes das variáveis
# - **features_info.txt:** contém a descrição das variáveis
# - **README.txt:** contém uma descrição do estudo e das bases
# - **activity_labels:** contém o código da atividade (inteiro entre 1 e 6) e a descrição
# - **subject_train.txt:** uma lista indicando que registro pertence a que indivíduo na base de treino
# - **X_train.txt:** as *features* (ou variáveis explicativas) da base de testes. Cada linha representa um registro das informações de um indivíduo em um intervalo de tempo de aproximadamente 1/0.3 segundo. As medidas estão em ordem temporal dentro do estudo, e o indivíduo que originou a medida está identificado na base subject_train.txt.
# - **y_train.txt:** Possui o mesmo número de linhas que X_test. Contém um número de 1 a 6 indicando a atividade que estava sendo realizada por aquele registro na base de treino.
# - **subject_test.txt:** uma lista indicando que registro pertence a que indivíduo na base de teste
# - **X_test.txt:** as *features* (ou variáveis explicativas) da base de testes. Cada linha representa um registro das informações de um indivíduo em um intervalo de tempo de aproximadamente 1/0.3 segundo. As medidas estão em ordem temporal dentro do estudo, e o indivíduo que originou a medida está identificado na base subject_test.txt.
# - **y_test.txt:** Possui o mesmo número de linhas que X_train. Contém um número de 1 a 6 indicando a atividade que estava sendo realizada por aquele registro na base de teste.
#
# Carregue as bases:
#
# 1. Faça o download dos arquivos.
# 2. Carregue a base ```features.txt``` em uma *Series* (por exemplo usando o comando ```pd.read_csv()```.
# 3. Carregue a base subject_train.txt em uma *Series*
# 4. Carregue a base X_train.txt
#     1. Faça com que as colunas deste *dataframe* tenham os nomes indicados em ```features.txt```
#     2. Sem alterar a ordem dos *dataframes*, coloque o indicador do indivíduo lido em ```subject_train.txt``` como uma variável a mais neste *dataframe***
#     3. Faça com que este *dataframe* tenha um índice duplo, composto pela ordem dos dados e pelo identificador do indivíduo
# 5. Com a mesma lógica, carregue a base X_test
#     1. Certifique-se de que tenha os nomes lidos em ```features.txt```
#     2. Coloque o identificador do sujeito lido em ```subject_test.txt```
#     3. Defina um índice duplo composto pela ordem do registro e o identificador do registro
# 6. Salve as bases em arquivos CSV para facilitar a leitura deles na terefa 2 deste módulo
# 7. Considere que esta base é maior que a da aula, tanto em linhas quanto em colunas. Selecione apenas as três primeiras colunas da base ('tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y' e 'tBodyAcc-mean()-Z'), para efeitos desse exercício.
#
# **OBS:** As bases já estão divididas em treino e teste, de modo que não vamos precisar da função ```train_test_split```.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import numpy as np
import matplotlib.pyplot as plt
import graphviz

from IPython.display import display
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### 2. Carregue a base ```features.txt``` em uma *Series*

# %%
features = pd.read_csv(r'C:\Users\earap\Documents\EBAC\DataScienceExcercises\Módulo 17 - Árvores II\ex026\UCI HAR Dataset\features.txt', sep="\s+", header=None, usecols=[1], names=["feature"])["feature"]

# %%
print(features.head())
# Out:
# 0    tBodyAcc-mean()-X
# 1    tBodyAcc-mean()-Y
# 2    tBodyAcc-mean()-Z
# 3     tBodyAcc-std()-X
# 4     tBodyAcc-std()-Y
# Name: feature, dtype: object

# %%
print(features.shape)
# Out:
# (561,)

# %%
print(features.dtypes)
# Out:
# object

# %% [markdown]
# ### 3. Carregue a base subject_train.txt em uma *Series*

# %%
subjects_train = pd.read_csv(
    r'C:\Users\earap\Documents\EBAC\DataScienceExcercises\Módulo 17 - Árvores II\ex026\UCI HAR Dataset\train\subject_train.txt',
    header=None,
    sep='\s+'  # Usa regex para separar por um ou mais espaços
)

# %%
print(subjects_train.head())
# Out:
#    0
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1

# %%
print(subjects_train.shape)
# Out:
# (7352, 1)

# %%
print(subjects_train.dtypes)
# Out:
# 0    int64
# dtype: object

# %% [markdown]
# ### 4. Carregue a base X_train.txt
# #### 1. Faça com que as colunas deste *dataframe* tenham os nomes indicados em ```features.txt```

# %%
X_train = pd.read_csv(r"C:\Users\earap\Documents\EBAC\DataScienceExcercises\Módulo 17 - Árvores II\ex026\UCI HAR Dataset\train\X_train.txt", delim_whitespace=True, header=None)
# Out:
# C:\Users\earap\AppData\Local\Temp\ipykernel_11608\2456642452.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   X_train = pd.read_csv(r"C:\Users\earap\Documents\EBAC\DataScienceExcercises\Módulo 17 - Árvores II\ex026\UCI HAR Dataset\train\X_train.txt", delim_whitespace=True, header=None)

# %%
print(X_train.head())
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1  0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2  0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3  0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4  0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
#
#         7         8         9    ...       551       552       553       554  \
# 0 -0.983185 -0.923527 -0.934724  ... -0.074323 -0.298676 -0.710304 -0.112754
# 1 -0.974914 -0.957686 -0.943068  ...  0.158075 -0.595051 -0.861499  0.053477
# 2 -0.963668 -0.977469 -0.938692  ...  0.414503 -0.390748 -0.760104 -0.118559
# 3 -0.982750 -0.989302 -0.938692  ...  0.404573 -0.117290 -0.482845 -0.036788
# 4 -0.979672 -0.990441 -0.942469  ...  0.087753 -0.351471 -0.699205  0.123320
#
#         555       556       557       558       559       560
# 0  0.030400 -0.464761 -0.018446 -0.841247  0.179941 -0.058627
# 1 -0.007435 -0.732626  0.703511 -0.844788  0.180289 -0.054317
# 2  0.177899  0.100699  0.808529 -0.848933  0.180637 -0.049118
# 3 -0.012892  0.640011 -0.485366 -0.848649  0.181935 -0.047663
# 4  0.122542  0.693578 -0.615971 -0.847865  0.185151 -0.043892
#
# [5 rows x 561 columns]

# %%
print(X_train.shape)
# Out:
# (7352, 561)

# %%
print(X_train.dtypes)
# Out:
# 0      float64
# 1      float64
# 2      float64
# 3      float64
# 4      float64
#         ...
# 556    float64
# 557    float64
# 558    float64
# 559    float64
# 560    float64
# Length: 561, dtype: object

# %%
X_train.columns = features

# %%
X_train.head(5)
# Out:
# feature  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0                 0.288585          -0.020294          -0.132905
# 1                 0.278419          -0.016411          -0.123520
# 2                 0.279653          -0.019467          -0.113462
# 3                 0.279174          -0.026201          -0.123283
# 4                 0.276629          -0.016570          -0.115362
#
# feature  tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
# 0               -0.995279         -0.983111         -0.913526
# 1               -0.998245         -0.975300         -0.960322
# 2               -0.995380         -0.967187         -0.978944
# 3               -0.996091         -0.983403         -0.990675
# 4               -0.998139         -0.980817         -0.990482
#
# feature  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  \
# 0               -0.995112         -0.983185         -0.923527
# 1               -0.998807         -0.974914         -0.957686
# 2               -0.996520         -0.963668         -0.977469
# 3               -0.997099         -0.982750         -0.989302
# 4               -0.998321         -0.979672         -0.990441
#
# feature  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-meanFreq()  \
# 0               -0.934724  ...                        -0.074323
# 1               -0.943068  ...                         0.158075
# 2               -0.938692  ...                         0.414503
# 3               -0.938692  ...                         0.404573
# 4               -0.942469  ...                         0.087753
#
# feature  fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# 0                              -0.298676                        -0.710304
# 1                              -0.595051                        -0.861499
# 2                              -0.390748                        -0.760104
# 3                              -0.117290                        -0.482845
# 4                              -0.351471                        -0.699205
#
# feature  angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                          -0.112754                              0.030400
# 1                           0.053477                             -0.007435
# 2                          -0.118559                              0.177899
# 3                          -0.036788                             -0.012892
# 4                           0.123320                              0.122542
#
# feature  angle(tBodyGyroMean,gravityMean)  \
# 0                               -0.464761
# 1                               -0.732626
# 2                                0.100699
# 3                                0.640011
# 4                                0.693578
#
# feature  angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                                   -0.018446             -0.841247
# 1                                    0.703511             -0.844788
# 2                                    0.808529             -0.848933
# 3                                   -0.485366             -0.848649
# 4                                   -0.615971             -0.847865
#
# feature  angle(Y,gravityMean)  angle(Z,gravityMean)
# 0                    0.179941             -0.058627
# 1                    0.180289             -0.054317
# 2                    0.180637             -0.049118
# 3                    0.181935             -0.047663
# 4                    0.185151             -0.043892
#
# [5 rows x 561 columns]

# %% [markdown]
# #### Passo 4.2: Adicionar a coluna do identificador do indivíduo

# %%
X_train.insert(0, "subject", subjects_train)

# %%
X_train
# Out:
# feature  subject  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              1           0.288585          -0.020294          -0.132905
# 1              1           0.278419          -0.016411          -0.123520
# 2              1           0.279653          -0.019467          -0.113462
# 3              1           0.279174          -0.026201          -0.123283
# 4              1           0.276629          -0.016570          -0.115362
# ...          ...                ...                ...                ...
# 7347          30           0.299665          -0.057193          -0.181233
# 7348          30           0.273853          -0.007749          -0.147468
# 7349          30           0.273387          -0.017011          -0.045022
# 7350          30           0.289654          -0.018843          -0.158281
# 7351          30           0.351503          -0.012423          -0.203867
#
# feature  tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
# 0               -0.995279         -0.983111         -0.913526
# 1               -0.998245         -0.975300         -0.960322
# 2               -0.995380         -0.967187         -0.978944
# 3               -0.996091         -0.983403         -0.990675
# 4               -0.998139         -0.980817         -0.990482
# ...                   ...               ...               ...
# 7347            -0.195387          0.039905          0.077078
# 7348            -0.235309          0.004816          0.059280
# 7349            -0.218218         -0.103822          0.274533
# 7350            -0.219139         -0.111412          0.268893
# 7351            -0.269270         -0.087212          0.177404
#
# feature  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  ...  \
# 0               -0.995112         -0.983185         -0.923527  ...
# 1               -0.998807         -0.974914         -0.957686  ...
# 2               -0.996520         -0.963668         -0.977469  ...
# 3               -0.997099         -0.982750         -0.989302  ...
# 4               -0.998321         -0.979672         -0.990441  ...
# ...                   ...               ...               ...  ...
# 7347            -0.282301          0.043616          0.060410  ...
# 7348            -0.322552         -0.029456          0.080585  ...
# 7349            -0.304515         -0.098913          0.332584  ...
# 7350            -0.310487         -0.068200          0.319473  ...
# 7351            -0.377404         -0.038678          0.229430  ...
#
# feature  fBodyBodyGyroJerkMag-meanFreq()  fBodyBodyGyroJerkMag-skewness()  \
# 0                              -0.074323                        -0.298676
# 1                               0.158075                        -0.595051
# 2                               0.414503                        -0.390748
# 3                               0.404573                        -0.117290
# 4                               0.087753                        -0.351471
# ...                                  ...                              ...
# 7347                           -0.070157                        -0.588433
# 7348                            0.165259                        -0.390738
# 7349                            0.195034                         0.025145
# 7350                            0.013865                         0.063907
# 7351                           -0.058402                        -0.387052
#
# feature  fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                              -0.710304                    -0.112754
# 1                              -0.861499                     0.053477
# 2                              -0.760104                    -0.118559
# 3                              -0.482845                    -0.036788
# 4                              -0.699205                     0.123320
# ...                                  ...                          ...
# 7347                           -0.880324                    -0.190437
# 7348                           -0.680744                     0.064907
# 7349                           -0.304029                     0.052806
# 7350                           -0.344314                    -0.101360
# 7351                           -0.740738                    -0.280088
#
# feature  angle(tBodyAccJerkMean),gravityMean)  \
# 0                                    0.030400
# 1                                   -0.007435
# 2                                    0.177899
# 3                                   -0.012892
# 4                                    0.122542
# ...                                       ...
# 7347                                 0.829718
# 7348                                 0.875679
# 7349                                -0.266724
# 7350                                 0.700740
# 7351                                -0.007739
#
# feature  angle(tBodyGyroMean,gravityMean)  \
# 0                               -0.464761
# 1                               -0.732626
# 2                                0.100699
# 3                                0.640011
# 4                                0.693578
# ...                                   ...
# 7347                             0.206972
# 7348                            -0.879033
# 7349                             0.864404
# 7350                             0.936674
# 7351                            -0.056088
#
# feature  angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                                   -0.018446             -0.841247
# 1                                    0.703511             -0.844788
# 2                                    0.808529             -0.848933
# 3                                   -0.485366             -0.848649
# 4                                   -0.615971             -0.847865
# ...                                       ...                   ...
# 7347                                -0.425619             -0.791883
# 7348                                 0.400219             -0.771840
# 7349                                 0.701169             -0.779133
# 7350                                -0.589479             -0.785181
# 7351                                -0.616956             -0.783267
#
# feature  angle(Y,gravityMean)  angle(Z,gravityMean)
# 0                    0.179941             -0.058627
# 1                    0.180289             -0.054317
# 2                    0.180637             -0.049118
# 3                    0.181935             -0.047663
# 4                    0.185151             -0.043892
# ...                       ...                   ...
# 7347                 0.238604              0.049819
# 7348                 0.252676              0.050053
# 7349                 0.249145              0.040811
# 7350                 0.246432              0.025339
# 7351                 0.246809              0.036695
#
# [7352 rows x 562 columns]

# %% [markdown]
# #### Passo 4.3: Criar índice duplo (ordem dos dados + identificador do indivíduo)

# %%
X_train.index = pd.MultiIndex.from_arrays([X_train.index, X_train["subject"]], names=["order", "subject"])

# %%
X_train
# Out:
# feature        subject  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  \
# order subject
# 0     1              1           0.288585          -0.020294
# 1     1              1           0.278419          -0.016411
# 2     1              1           0.279653          -0.019467
# 3     1              1           0.279174          -0.026201
# 4     1              1           0.276629          -0.016570
# ...                ...                ...                ...
# 7347  30            30           0.299665          -0.057193
# 7348  30            30           0.273853          -0.007749
# 7349  30            30           0.273387          -0.017011
# 7350  30            30           0.289654          -0.018843
# 7351  30            30           0.351503          -0.012423
#
# feature        tBodyAcc-mean()-Z  tBodyAcc-std()-X  tBodyAcc-std()-Y  \
# order subject
# 0     1                -0.132905         -0.995279         -0.983111
# 1     1                -0.123520         -0.998245         -0.975300
# 2     1                -0.113462         -0.995380         -0.967187
# 3     1                -0.123283         -0.996091         -0.983403
# 4     1                -0.115362         -0.998139         -0.980817
# ...                          ...               ...               ...
# 7347  30               -0.181233         -0.195387          0.039905
# 7348  30               -0.147468         -0.235309          0.004816
# 7349  30               -0.045022         -0.218218         -0.103822
# 7350  30               -0.158281         -0.219139         -0.111412
# 7351  30               -0.203867         -0.269270         -0.087212
#
# feature        tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# order subject
# 0     1               -0.913526         -0.995112         -0.983185
# 1     1               -0.960322         -0.998807         -0.974914
# 2     1               -0.978944         -0.996520         -0.963668
# 3     1               -0.990675         -0.997099         -0.982750
# 4     1               -0.990482         -0.998321         -0.979672
# ...                         ...               ...               ...
# 7347  30               0.077078         -0.282301          0.043616
# 7348  30               0.059280         -0.322552         -0.029456
# 7349  30               0.274533         -0.304515         -0.098913
# 7350  30               0.268893         -0.310487         -0.068200
# 7351  30               0.177404         -0.377404         -0.038678
#
# feature        tBodyAcc-mad()-Z  ...  fBodyBodyGyroJerkMag-meanFreq()  \
# order subject                    ...
# 0     1               -0.923527  ...                        -0.074323
# 1     1               -0.957686  ...                         0.158075
# 2     1               -0.977469  ...                         0.414503
# 3     1               -0.989302  ...                         0.404573
# 4     1               -0.990441  ...                         0.087753
# ...                         ...  ...                              ...
# 7347  30               0.060410  ...                        -0.070157
# 7348  30               0.080585  ...                         0.165259
# 7349  30               0.332584  ...                         0.195034
# 7350  30               0.319473  ...                         0.013865
# 7351  30               0.229430  ...                        -0.058402
#
# feature        fBodyBodyGyroJerkMag-skewness()  \
# order subject
# 0     1                              -0.298676
# 1     1                              -0.595051
# 2     1                              -0.390748
# 3     1                              -0.117290
# 4     1                              -0.351471
# ...                                        ...
# 7347  30                             -0.588433
# 7348  30                             -0.390738
# 7349  30                              0.025145
# 7350  30                              0.063907
# 7351  30                             -0.387052
#
# feature        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# order subject
# 0     1                              -0.710304                    -0.112754
# 1     1                              -0.861499                     0.053477
# 2     1                              -0.760104                    -0.118559
# 3     1                              -0.482845                    -0.036788
# 4     1                              -0.699205                     0.123320
# ...                                        ...                          ...
# 7347  30                             -0.880324                    -0.190437
# 7348  30                             -0.680744                     0.064907
# 7349  30                             -0.304029                     0.052806
# 7350  30                             -0.344314                    -0.101360
# 7351  30                             -0.740738                    -0.280088
#
# feature        angle(tBodyAccJerkMean),gravityMean)  \
# order subject
# 0     1                                    0.030400
# 1     1                                   -0.007435
# 2     1                                    0.177899
# 3     1                                   -0.012892
# 4     1                                    0.122542
# ...                                             ...
# 7347  30                                   0.829718
# 7348  30                                   0.875679
# 7349  30                                  -0.266724
# 7350  30                                   0.700740
# 7351  30                                  -0.007739
#
# feature        angle(tBodyGyroMean,gravityMean)  \
# order subject
# 0     1                               -0.464761
# 1     1                               -0.732626
# 2     1                                0.100699
# 3     1                                0.640011
# 4     1                                0.693578
# ...                                         ...
# 7347  30                               0.206972
# 7348  30                              -0.879033
# 7349  30                               0.864404
# 7350  30                               0.936674
# 7351  30                              -0.056088
#
# feature        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# order subject
# 0     1                                   -0.018446             -0.841247
# 1     1                                    0.703511             -0.844788
# 2     1                                    0.808529             -0.848933
# 3     1                                   -0.485366             -0.848649
# 4     1                                   -0.615971             -0.847865
# ...                                             ...                   ...
# 7347  30                                  -0.425619             -0.791883
# 7348  30                                   0.400219             -0.771840
# 7349  30                                   0.701169             -0.779133
# 7350  30                                  -0.589479             -0.785181
# 7351  30                                  -0.616956             -0.783267
#
# feature        angle(Y,gravityMean)  angle(Z,gravityMean)
# order subject
# 0     1                    0.179941             -0.058627
# 1     1                    0.180289             -0.054317
# 2     1                    0.180637             -0.049118
# 3     1                    0.181935             -0.047663
# 4     1                    0.185151             -0.043892
# ...                             ...                   ...
# 7347  30                   0.238604              0.049819
# 7348  30                   0.252676              0.050053
# 7349  30                   0.249145              0.040811
# 7350  30                   0.246432              0.025339
# 7351  30                   0.246809              0.036695
#
# [7352 rows x 562 columns]

# %% [markdown]
# ##### Remover a coluna "subject", pois já está no índice

# %%
X_train = X_train.drop(columns=["subject"])

# %%
X_train.head()
# Out:
# feature        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# order subject
# 0     1                 0.288585          -0.020294          -0.132905
# 1     1                 0.278419          -0.016411          -0.123520
# 2     1                 0.279653          -0.019467          -0.113462
# 3     1                 0.279174          -0.026201          -0.123283
# 4     1                 0.276629          -0.016570          -0.115362
#
# feature        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
# order subject
# 0     1               -0.995279         -0.983111         -0.913526
# 1     1               -0.998245         -0.975300         -0.960322
# 2     1               -0.995380         -0.967187         -0.978944
# 3     1               -0.996091         -0.983403         -0.990675
# 4     1               -0.998139         -0.980817         -0.990482
#
# feature        tBodyAcc-mad()-X  tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  \
# order subject
# 0     1               -0.995112         -0.983185         -0.923527
# 1     1               -0.998807         -0.974914         -0.957686
# 2     1               -0.996520         -0.963668         -0.977469
# 3     1               -0.997099         -0.982750         -0.989302
# 4     1               -0.998321         -0.979672         -0.990441
#
# feature        tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-meanFreq()  \
# order subject                    ...
# 0     1               -0.934724  ...                        -0.074323
# 1     1               -0.943068  ...                         0.158075
# 2     1               -0.938692  ...                         0.414503
# 3     1               -0.938692  ...                         0.404573
# 4     1               -0.942469  ...                         0.087753
#
# feature        fBodyBodyGyroJerkMag-skewness()  \
# order subject
# 0     1                              -0.298676
# 1     1                              -0.595051
# 2     1                              -0.390748
# 3     1                              -0.117290
# 4     1                              -0.351471
#
# feature        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# order subject
# 0     1                              -0.710304                    -0.112754
# 1     1                              -0.861499                     0.053477
# 2     1                              -0.760104                    -0.118559
# 3     1                              -0.482845                    -0.036788
# 4     1                              -0.699205                     0.123320
#
# feature        angle(tBodyAccJerkMean),gravityMean)  \
# order subject
# 0     1                                    0.030400
# 1     1                                   -0.007435
# 2     1                                    0.177899
# 3     1                                   -0.012892
# 4     1                                    0.122542
#
# feature        angle(tBodyGyroMean,gravityMean)  \
# order subject
# 0     1                               -0.464761
# 1     1                               -0.732626
# 2     1                                0.100699
# 3     1                                0.640011
# 4     1                                0.693578
#
# feature        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# order subject
# 0     1                                   -0.018446             -0.841247
# 1     1                                    0.703511             -0.844788
# 2     1                                    0.808529             -0.848933
# 3     1                                   -0.485366             -0.848649
# 4     1                                   -0.615971             -0.847865
#
# feature        angle(Y,gravityMean)  angle(Z,gravityMean)
# order subject
# 0     1                    0.179941             -0.058627
# 1     1                    0.180289             -0.054317
# 2     1                    0.180637             -0.049118
# 3     1                    0.181935             -0.047663
# 4     1                    0.185151             -0.043892
#
# [5 rows x 561 columns]

# %% [markdown]
# ### 5. Com a mesma lógica, carregue a base X_test
# #### 1. Certifique-se de que tenha os nomes lidos em ```features.txt```

# %%
features.head(10)
# Out:
# 0    tBodyAcc-mean()-X
# 1    tBodyAcc-mean()-Y
# 2    tBodyAcc-mean()-Z
# 3     tBodyAcc-std()-X
# 4     tBodyAcc-std()-Y
# 5     tBodyAcc-std()-Z
# 6     tBodyAcc-mad()-X
# 7     tBodyAcc-mad()-Y
# 8     tBodyAcc-mad()-Z
# 9     tBodyAcc-max()-X
# Name: feature, dtype: object

# %%
X_test = pd.read_csv(r"C:\Users\earap\Documents\EBAC\DataScienceExcercises\Módulo 17 - Árvores II\ex026\UCI HAR Dataset\test\X_test.txt", delim_whitespace=True, header=None)
# Out:
# C:\Users\earap\AppData\Local\Temp\ipykernel_11608\3197307694.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   X_test = pd.read_csv(r"C:\Users\earap\Documents\EBAC\DataScienceExcercises\Módulo 17 - Árvores II\ex026\UCI HAR Dataset\test\X_test.txt", delim_whitespace=True, header=None)

# %%
print(X_test.head())
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.257178 -0.023285 -0.014654 -0.938404 -0.920091 -0.667683 -0.952501
# 1  0.286027 -0.013163 -0.119083 -0.975415 -0.967458 -0.944958 -0.986799
# 2  0.275485 -0.026050 -0.118152 -0.993819 -0.969926 -0.962748 -0.994403
# 3  0.270298 -0.032614 -0.117520 -0.994743 -0.973268 -0.967091 -0.995274
# 4  0.274833 -0.027848 -0.129527 -0.993852 -0.967445 -0.978295 -0.994111
#
#         7         8         9    ...       551       552       553       554  \
# 0 -0.925249 -0.674302 -0.894088  ...  0.071645 -0.330370 -0.705974  0.006462
# 1 -0.968401 -0.945823 -0.894088  ... -0.401189 -0.121845 -0.594944 -0.083495
# 2 -0.970735 -0.963483 -0.939260  ...  0.062891 -0.190422 -0.640736 -0.034956
# 3 -0.974471 -0.968897 -0.938610  ...  0.116695 -0.344418 -0.736124 -0.017067
# 4 -0.965953 -0.977346 -0.938610  ... -0.121711 -0.534685 -0.846595 -0.002223
#
#         555       556       557       558       559       560
# 0  0.162920 -0.825886  0.271151 -0.720009  0.276801 -0.057978
# 1  0.017500 -0.434375  0.920593 -0.698091  0.281343 -0.083898
# 2  0.202302  0.064103  0.145068 -0.702771  0.280083 -0.079346
# 3  0.154438  0.340134  0.296407 -0.698954  0.284114 -0.077108
# 4 -0.040046  0.736715 -0.118545 -0.692245  0.290722 -0.073857
#
# [5 rows x 561 columns]

# %%
print(X_test.shape)
# Out:
# (2947, 561)

# %%
print(X_test.dtypes)
# Out:
# 0      float64
# 1      float64
# 2      float64
# 3      float64
# 4      float64
#         ...
# 556    float64
# 557    float64
# 558    float64
# 559    float64
# 560    float64
# Length: 561, dtype: object

# %%
X_test.columns = features

# %%
X_test.head(5)
# Out:
# feature  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0                 0.257178          -0.023285          -0.014654
# 1                 0.286027          -0.013163          -0.119083
# 2                 0.275485          -0.026050          -0.118152
# 3                 0.270298          -0.032614          -0.117520
# 4                 0.274833          -0.027848          -0.129527
#
# feature  tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
# 0               -0.938404         -0.920091         -0.667683
# 1               -0.975415         -0.967458         -0.944958
# 2               -0.993819         -0.969926         -0.962748
# 3               -0.994743         -0.973268         -0.967091
# 4               -0.993852         -0.967445         -0.978295
#
# feature  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  \
# 0               -0.952501         -0.925249         -0.674302
# 1               -0.986799         -0.968401         -0.945823
# 2               -0.994403         -0.970735         -0.963483
# 3               -0.995274         -0.974471         -0.968897
# 4               -0.994111         -0.965953         -0.977346
#
# feature  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-meanFreq()  \
# 0               -0.894088  ...                         0.071645
# 1               -0.894088  ...                        -0.401189
# 2               -0.939260  ...                         0.062891
# 3               -0.938610  ...                         0.116695
# 4               -0.938610  ...                        -0.121711
#
# feature  fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# 0                              -0.330370                        -0.705974
# 1                              -0.121845                        -0.594944
# 2                              -0.190422                        -0.640736
# 3                              -0.344418                        -0.736124
# 4                              -0.534685                        -0.846595
#
# feature  angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                           0.006462                              0.162920
# 1                          -0.083495                              0.017500
# 2                          -0.034956                              0.202302
# 3                          -0.017067                              0.154438
# 4                          -0.002223                             -0.040046
#
# feature  angle(tBodyGyroMean,gravityMean)  \
# 0                               -0.825886
# 1                               -0.434375
# 2                                0.064103
# 3                                0.340134
# 4                                0.736715
#
# feature  angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                                    0.271151             -0.720009
# 1                                    0.920593             -0.698091
# 2                                    0.145068             -0.702771
# 3                                    0.296407             -0.698954
# 4                                   -0.118545             -0.692245
#
# feature  angle(Y,gravityMean)  angle(Z,gravityMean)
# 0                    0.276801             -0.057978
# 1                    0.281343             -0.083898
# 2                    0.280083             -0.079346
# 3                    0.284114             -0.077108
# 4                    0.290722             -0.073857
#
# [5 rows x 561 columns]

# %% [markdown]
# ####    2. Coloque o identificador do sujeito lido em ```subject_test.txt```

# %%
subjects_test = pd.read_csv(
    r'C:\Users\earap\Documents\EBAC\DataScienceExcercises\Módulo 17 - Árvores II\ex026\UCI HAR Dataset\test\subject_test.txt',
    header=None,
    sep='\s+'  # Usa regex para separar por um ou mais espaços
)

# %%
print(subjects_test.head())
# Out:
#    0
# 0  2
# 1  2
# 2  2
# 3  2
# 4  2

# %%
print(subjects_test.shape)
# Out:
# (2947, 1)

# %%
print(subjects_test.dtypes)
# Out:
# 0    int64
# dtype: object

# %%
X_test
# Out:
# feature  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0                 0.257178          -0.023285          -0.014654
# 1                 0.286027          -0.013163          -0.119083
# 2                 0.275485          -0.026050          -0.118152
# 3                 0.270298          -0.032614          -0.117520
# 4                 0.274833          -0.027848          -0.129527
# ...                    ...                ...                ...
# 2942              0.310155          -0.053391          -0.099109
# 2943              0.363385          -0.039214          -0.105915
# 2944              0.349966           0.030077          -0.115788
# 2945              0.237594           0.018467          -0.096499
# 2946              0.153627          -0.018437          -0.137018
#
# feature  tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
# 0               -0.938404         -0.920091         -0.667683
# 1               -0.975415         -0.967458         -0.944958
# 2               -0.993819         -0.969926         -0.962748
# 3               -0.994743         -0.973268         -0.967091
# 4               -0.993852         -0.967445         -0.978295
# ...                   ...               ...               ...
# 2942            -0.287866         -0.140589         -0.215088
# 2943            -0.305388          0.028148         -0.196373
# 2944            -0.329638         -0.042143         -0.250181
# 2945            -0.323114         -0.229775         -0.207574
# 2946            -0.330046         -0.195253         -0.164339
#
# feature  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  \
# 0               -0.952501         -0.925249         -0.674302
# 1               -0.986799         -0.968401         -0.945823
# 2               -0.994403         -0.970735         -0.963483
# 3               -0.995274         -0.974471         -0.968897
# 4               -0.994111         -0.965953         -0.977346
# ...                   ...               ...               ...
# 2942            -0.356083         -0.148775         -0.232057
# 2943            -0.373540         -0.030036         -0.270237
# 2944            -0.388017         -0.133257         -0.347029
# 2945            -0.392380         -0.279610         -0.289477
# 2946            -0.430974         -0.218295         -0.229933
#
# feature  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-meanFreq()  \
# 0               -0.894088  ...                         0.071645
# 1               -0.894088  ...                        -0.401189
# 2               -0.939260  ...                         0.062891
# 3               -0.938610  ...                         0.116695
# 4               -0.938610  ...                        -0.121711
# ...                   ...  ...                              ...
# 2942             0.185361  ...                         0.074472
# 2943             0.185361  ...                         0.101859
# 2944             0.007471  ...                        -0.066249
# 2945             0.007471  ...                        -0.046467
# 2946            -0.111527  ...                        -0.010386
#
# feature  fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# 0                              -0.330370                        -0.705974
# 1                              -0.121845                        -0.594944
# 2                              -0.190422                        -0.640736
# 3                              -0.344418                        -0.736124
# 4                              -0.534685                        -0.846595
# ...                                  ...                              ...
# 2942                           -0.376278                        -0.750809
# 2943                           -0.320418                        -0.700274
# 2944                           -0.118854                        -0.467179
# 2945                           -0.205445                        -0.617737
# 2946                           -0.072237                        -0.436940
#
# feature  angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                           0.006462                              0.162920
# 1                          -0.083495                              0.017500
# 2                          -0.034956                              0.202302
# 3                          -0.017067                              0.154438
# 4                          -0.002223                             -0.040046
# ...                              ...                                   ...
# 2942                       -0.337422                              0.346295
# 2943                       -0.736701                             -0.372889
# 2944                       -0.181560                              0.088574
# 2945                        0.444558                             -0.819188
# 2946                        0.598808                             -0.287951
#
# feature  angle(tBodyGyroMean,gravityMean)  \
# 0                               -0.825886
# 1                               -0.434375
# 2                                0.064103
# 3                                0.340134
# 4                                0.736715
# ...                                   ...
# 2942                             0.884904
# 2943                            -0.657421
# 2944                             0.696663
# 2945                             0.929294
# 2946                             0.876030
#
# feature  angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                                    0.271151             -0.720009
# 1                                    0.920593             -0.698091
# 2                                    0.145068             -0.702771
# 3                                    0.296407             -0.698954
# 4                                   -0.118545             -0.692245
# ...                                       ...                   ...
# 2942                                -0.698885             -0.651732
# 2943                                 0.322549             -0.655181
# 2944                                 0.363139             -0.655357
# 2945                                -0.008398             -0.659719
# 2946                                -0.024965             -0.660080
#
# feature  angle(Y,gravityMean)  angle(Z,gravityMean)
# 0                    0.276801             -0.057978
# 1                    0.281343             -0.083898
# 2                    0.280083             -0.079346
# 3                    0.284114             -0.077108
# 4                    0.290722             -0.073857
# ...                       ...                   ...
# 2942                 0.274627              0.184784
# 2943                 0.273578              0.182412
# 2944                 0.274479              0.181184
# 2945                 0.264782              0.187563
# 2946                 0.263936              0.188103
#
# [2947 rows x 561 columns]

# %%
X_test.insert(0, "subject", subjects_test)

# %%
X_test
# Out:
# feature  subject  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              2           0.257178          -0.023285          -0.014654
# 1              2           0.286027          -0.013163          -0.119083
# 2              2           0.275485          -0.026050          -0.118152
# 3              2           0.270298          -0.032614          -0.117520
# 4              2           0.274833          -0.027848          -0.129527
# ...          ...                ...                ...                ...
# 2942          24           0.310155          -0.053391          -0.099109
# 2943          24           0.363385          -0.039214          -0.105915
# 2944          24           0.349966           0.030077          -0.115788
# 2945          24           0.237594           0.018467          -0.096499
# 2946          24           0.153627          -0.018437          -0.137018
#
# feature  tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
# 0               -0.938404         -0.920091         -0.667683
# 1               -0.975415         -0.967458         -0.944958
# 2               -0.993819         -0.969926         -0.962748
# 3               -0.994743         -0.973268         -0.967091
# 4               -0.993852         -0.967445         -0.978295
# ...                   ...               ...               ...
# 2942            -0.287866         -0.140589         -0.215088
# 2943            -0.305388          0.028148         -0.196373
# 2944            -0.329638         -0.042143         -0.250181
# 2945            -0.323114         -0.229775         -0.207574
# 2946            -0.330046         -0.195253         -0.164339
#
# feature  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  ...  \
# 0               -0.952501         -0.925249         -0.674302  ...
# 1               -0.986799         -0.968401         -0.945823  ...
# 2               -0.994403         -0.970735         -0.963483  ...
# 3               -0.995274         -0.974471         -0.968897  ...
# 4               -0.994111         -0.965953         -0.977346  ...
# ...                   ...               ...               ...  ...
# 2942            -0.356083         -0.148775         -0.232057  ...
# 2943            -0.373540         -0.030036         -0.270237  ...
# 2944            -0.388017         -0.133257         -0.347029  ...
# 2945            -0.392380         -0.279610         -0.289477  ...
# 2946            -0.430974         -0.218295         -0.229933  ...
#
# feature  fBodyBodyGyroJerkMag-meanFreq()  fBodyBodyGyroJerkMag-skewness()  \
# 0                               0.071645                        -0.330370
# 1                              -0.401189                        -0.121845
# 2                               0.062891                        -0.190422
# 3                               0.116695                        -0.344418
# 4                              -0.121711                        -0.534685
# ...                                  ...                              ...
# 2942                            0.074472                        -0.376278
# 2943                            0.101859                        -0.320418
# 2944                           -0.066249                        -0.118854
# 2945                           -0.046467                        -0.205445
# 2946                           -0.010386                        -0.072237
#
# feature  fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                              -0.705974                     0.006462
# 1                              -0.594944                    -0.083495
# 2                              -0.640736                    -0.034956
# 3                              -0.736124                    -0.017067
# 4                              -0.846595                    -0.002223
# ...                                  ...                          ...
# 2942                           -0.750809                    -0.337422
# 2943                           -0.700274                    -0.736701
# 2944                           -0.467179                    -0.181560
# 2945                           -0.617737                     0.444558
# 2946                           -0.436940                     0.598808
#
# feature  angle(tBodyAccJerkMean),gravityMean)  \
# 0                                    0.162920
# 1                                    0.017500
# 2                                    0.202302
# 3                                    0.154438
# 4                                   -0.040046
# ...                                       ...
# 2942                                 0.346295
# 2943                                -0.372889
# 2944                                 0.088574
# 2945                                -0.819188
# 2946                                -0.287951
#
# feature  angle(tBodyGyroMean,gravityMean)  \
# 0                               -0.825886
# 1                               -0.434375
# 2                                0.064103
# 3                                0.340134
# 4                                0.736715
# ...                                   ...
# 2942                             0.884904
# 2943                            -0.657421
# 2944                             0.696663
# 2945                             0.929294
# 2946                             0.876030
#
# feature  angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                                    0.271151             -0.720009
# 1                                    0.920593             -0.698091
# 2                                    0.145068             -0.702771
# 3                                    0.296407             -0.698954
# 4                                   -0.118545             -0.692245
# ...                                       ...                   ...
# 2942                                -0.698885             -0.651732
# 2943                                 0.322549             -0.655181
# 2944                                 0.363139             -0.655357
# 2945                                -0.008398             -0.659719
# 2946                                -0.024965             -0.660080
#
# feature  angle(Y,gravityMean)  angle(Z,gravityMean)
# 0                    0.276801             -0.057978
# 1                    0.281343             -0.083898
# 2                    0.280083             -0.079346
# 3                    0.284114             -0.077108
# 4                    0.290722             -0.073857
# ...                       ...                   ...
# 2942                 0.274627              0.184784
# 2943                 0.273578              0.182412
# 2944                 0.274479              0.181184
# 2945                 0.264782              0.187563
# 2946                 0.263936              0.188103
#
# [2947 rows x 562 columns]

# %% [markdown]
# ####    3. Defina um índice duplo composto pela ordem do registro e o identificador do registro

# %%
X_test.index = pd.MultiIndex.from_arrays([X_test.index, X_test["subject"]], names=["order", "subject"])

# %%
X_test
# Out:
# feature        subject  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  \
# order subject
# 0     2              2           0.257178          -0.023285
# 1     2              2           0.286027          -0.013163
# 2     2              2           0.275485          -0.026050
# 3     2              2           0.270298          -0.032614
# 4     2              2           0.274833          -0.027848
# ...                ...                ...                ...
# 2942  24            24           0.310155          -0.053391
# 2943  24            24           0.363385          -0.039214
# 2944  24            24           0.349966           0.030077
# 2945  24            24           0.237594           0.018467
# 2946  24            24           0.153627          -0.018437
#
# feature        tBodyAcc-mean()-Z  tBodyAcc-std()-X  tBodyAcc-std()-Y  \
# order subject
# 0     2                -0.014654         -0.938404         -0.920091
# 1     2                -0.119083         -0.975415         -0.967458
# 2     2                -0.118152         -0.993819         -0.969926
# 3     2                -0.117520         -0.994743         -0.973268
# 4     2                -0.129527         -0.993852         -0.967445
# ...                          ...               ...               ...
# 2942  24               -0.099109         -0.287866         -0.140589
# 2943  24               -0.105915         -0.305388          0.028148
# 2944  24               -0.115788         -0.329638         -0.042143
# 2945  24               -0.096499         -0.323114         -0.229775
# 2946  24               -0.137018         -0.330046         -0.195253
#
# feature        tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# order subject
# 0     2               -0.667683         -0.952501         -0.925249
# 1     2               -0.944958         -0.986799         -0.968401
# 2     2               -0.962748         -0.994403         -0.970735
# 3     2               -0.967091         -0.995274         -0.974471
# 4     2               -0.978295         -0.994111         -0.965953
# ...                         ...               ...               ...
# 2942  24              -0.215088         -0.356083         -0.148775
# 2943  24              -0.196373         -0.373540         -0.030036
# 2944  24              -0.250181         -0.388017         -0.133257
# 2945  24              -0.207574         -0.392380         -0.279610
# 2946  24              -0.164339         -0.430974         -0.218295
#
# feature        tBodyAcc-mad()-Z  ...  fBodyBodyGyroJerkMag-meanFreq()  \
# order subject                    ...
# 0     2               -0.674302  ...                         0.071645
# 1     2               -0.945823  ...                        -0.401189
# 2     2               -0.963483  ...                         0.062891
# 3     2               -0.968897  ...                         0.116695
# 4     2               -0.977346  ...                        -0.121711
# ...                         ...  ...                              ...
# 2942  24              -0.232057  ...                         0.074472
# 2943  24              -0.270237  ...                         0.101859
# 2944  24              -0.347029  ...                        -0.066249
# 2945  24              -0.289477  ...                        -0.046467
# 2946  24              -0.229933  ...                        -0.010386
#
# feature        fBodyBodyGyroJerkMag-skewness()  \
# order subject
# 0     2                              -0.330370
# 1     2                              -0.121845
# 2     2                              -0.190422
# 3     2                              -0.344418
# 4     2                              -0.534685
# ...                                        ...
# 2942  24                             -0.376278
# 2943  24                             -0.320418
# 2944  24                             -0.118854
# 2945  24                             -0.205445
# 2946  24                             -0.072237
#
# feature        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# order subject
# 0     2                              -0.705974                     0.006462
# 1     2                              -0.594944                    -0.083495
# 2     2                              -0.640736                    -0.034956
# 3     2                              -0.736124                    -0.017067
# 4     2                              -0.846595                    -0.002223
# ...                                        ...                          ...
# 2942  24                             -0.750809                    -0.337422
# 2943  24                             -0.700274                    -0.736701
# 2944  24                             -0.467179                    -0.181560
# 2945  24                             -0.617737                     0.444558
# 2946  24                             -0.436940                     0.598808
#
# feature        angle(tBodyAccJerkMean),gravityMean)  \
# order subject
# 0     2                                    0.162920
# 1     2                                    0.017500
# 2     2                                    0.202302
# 3     2                                    0.154438
# 4     2                                   -0.040046
# ...                                             ...
# 2942  24                                   0.346295
# 2943  24                                  -0.372889
# 2944  24                                   0.088574
# 2945  24                                  -0.819188
# 2946  24                                  -0.287951
#
# feature        angle(tBodyGyroMean,gravityMean)  \
# order subject
# 0     2                               -0.825886
# 1     2                               -0.434375
# 2     2                                0.064103
# 3     2                                0.340134
# 4     2                                0.736715
# ...                                         ...
# 2942  24                               0.884904
# 2943  24                              -0.657421
# 2944  24                               0.696663
# 2945  24                               0.929294
# 2946  24                               0.876030
#
# feature        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# order subject
# 0     2                                    0.271151             -0.720009
# 1     2                                    0.920593             -0.698091
# 2     2                                    0.145068             -0.702771
# 3     2                                    0.296407             -0.698954
# 4     2                                   -0.118545             -0.692245
# ...                                             ...                   ...
# 2942  24                                  -0.698885             -0.651732
# 2943  24                                   0.322549             -0.655181
# 2944  24                                   0.363139             -0.655357
# 2945  24                                  -0.008398             -0.659719
# 2946  24                                  -0.024965             -0.660080
#
# feature        angle(Y,gravityMean)  angle(Z,gravityMean)
# order subject
# 0     2                    0.276801             -0.057978
# 1     2                    0.281343             -0.083898
# 2     2                    0.280083             -0.079346
# 3     2                    0.284114             -0.077108
# 4     2                    0.290722             -0.073857
# ...                             ...                   ...
# 2942  24                   0.274627              0.184784
# 2943  24                   0.273578              0.182412
# 2944  24                   0.274479              0.181184
# 2945  24                   0.264782              0.187563
# 2946  24                   0.263936              0.188103
#
# [2947 rows x 562 columns]

# %% [markdown]
# #### Remover a coluna "subject", pois já está no índice

# %%
del X_test["subject"]

# %%
X_test.head()
# Out:
# feature        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# order subject
# 0     2                 0.257178          -0.023285          -0.014654
# 1     2                 0.286027          -0.013163          -0.119083
# 2     2                 0.275485          -0.026050          -0.118152
# 3     2                 0.270298          -0.032614          -0.117520
# 4     2                 0.274833          -0.027848          -0.129527
#
# feature        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
# order subject
# 0     2               -0.938404         -0.920091         -0.667683
# 1     2               -0.975415         -0.967458         -0.944958
# 2     2               -0.993819         -0.969926         -0.962748
# 3     2               -0.994743         -0.973268         -0.967091
# 4     2               -0.993852         -0.967445         -0.978295
#
# feature        tBodyAcc-mad()-X  tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  \
# order subject
# 0     2               -0.952501         -0.925249         -0.674302
# 1     2               -0.986799         -0.968401         -0.945823
# 2     2               -0.994403         -0.970735         -0.963483
# 3     2               -0.995274         -0.974471         -0.968897
# 4     2               -0.994111         -0.965953         -0.977346
#
# feature        tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-meanFreq()  \
# order subject                    ...
# 0     2               -0.894088  ...                         0.071645
# 1     2               -0.894088  ...                        -0.401189
# 2     2               -0.939260  ...                         0.062891
# 3     2               -0.938610  ...                         0.116695
# 4     2               -0.938610  ...                        -0.121711
#
# feature        fBodyBodyGyroJerkMag-skewness()  \
# order subject
# 0     2                              -0.330370
# 1     2                              -0.121845
# 2     2                              -0.190422
# 3     2                              -0.344418
# 4     2                              -0.534685
#
# feature        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# order subject
# 0     2                              -0.705974                     0.006462
# 1     2                              -0.594944                    -0.083495
# 2     2                              -0.640736                    -0.034956
# 3     2                              -0.736124                    -0.017067
# 4     2                              -0.846595                    -0.002223
#
# feature        angle(tBodyAccJerkMean),gravityMean)  \
# order subject
# 0     2                                    0.162920
# 1     2                                    0.017500
# 2     2                                    0.202302
# 3     2                                    0.154438
# 4     2                                   -0.040046
#
# feature        angle(tBodyGyroMean,gravityMean)  \
# order subject
# 0     2                               -0.825886
# 1     2                               -0.434375
# 2     2                                0.064103
# 3     2                                0.340134
# 4     2                                0.736715
#
# feature        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# order subject
# 0     2                                    0.271151             -0.720009
# 1     2                                    0.920593             -0.698091
# 2     2                                    0.145068             -0.702771
# 3     2                                    0.296407             -0.698954
# 4     2                                   -0.118545             -0.692245
#
# feature        angle(Y,gravityMean)  angle(Z,gravityMean)
# order subject
# 0     2                    0.276801             -0.057978
# 1     2                    0.281343             -0.083898
# 2     2                    0.280083             -0.079346
# 3     2                    0.284114             -0.077108
# 4     2                    0.290722             -0.073857
#
# [5 rows x 561 columns]

# %% [markdown]
# ### Passo 6: Salvar a base em arquivos CSV

# %%
X_train.to_csv("X_train_processed.csv")
X_test.to_csv("X_test_processed.csv")
features.to_csv("features_processed.csv", index=False)
subjects_train.to_csv("subjects_train_processed.csv", index=False)
subjects_test.to_csv("subjects_test_processed.csv", index=False)

# %% [markdown]
# ### Passo 7: Selecionar apenas as três primeiras colunas para efeitos do exercício

# %%
X_train_filtered = X_train[["tBodyAcc-mean()-X", "tBodyAcc-mean()-Y", "tBodyAcc-mean()-Z"]]
X_test_filtered = X_test[["tBodyAcc-mean()-X", "tBodyAcc-mean()-Y", "tBodyAcc-mean()-Z"]]

# %%
X_train_filtered.to_csv("X_train_filtered.csv")
X_test_filtered.to_csv("X_test_filtered.csv")

# %%
X_train_filtered.head()
# Out:
# feature        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z
# order subject
# 0     1                 0.288585          -0.020294          -0.132905
# 1     1                 0.278419          -0.016411          -0.123520
# 2     1                 0.279653          -0.019467          -0.113462
# 3     1                 0.279174          -0.026201          -0.123283
# 4     1                 0.276629          -0.016570          -0.115362

# %%
X_test_filtered.head()
# Out:
# feature        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z
# order subject
# 0     2                 0.257178          -0.023285          -0.014654
# 1     2                 0.286027          -0.013163          -0.119083
# 2     2                 0.275485          -0.026050          -0.118152
# 3     2                 0.270298          -0.032614          -0.117520
# 4     2                 0.274833          -0.027848          -0.129527

# %% [markdown]
# ## 2. Ajustar uma árvore de decisão
#
# - 2.1 ajuste uma árvore de decisão com número mínimo de observações por folha = 20. Certifique-se de que você esteja utilizando apenas as 3 variáveis indicadas no exercício anterior.
# - 2.2 Calcule os ccp_alphas. Como feito em aula, certifique-se de que todos os valores são positivos, e selecione apenas valores únicos.
# - 2.3 Considere que vamos fazer uma árvore para cada valor de ```ccp_alpha```. Para ter um pouco mais de velocidade, crie uma coleção de dados com os ```ccp_alphas```, considerando apenas 1 a cada 5 valores. Dica: utilize o slicing do tipo ```array[::5]``` para isto. Caso se sinta seguro, fique à vontade para utilizar mais valores de ```ccp_alpha```.

# %% [markdown]
# ### 2.1 ajuste uma árvore de decisão com número mínimo de observações por folha = 20. Certifique-se de que você esteja utilizando apenas as 3 variáveis indicadas no exercício anterior.

# %%
X_train = pd.read_csv("X_train_filtered.csv", index_col=[0, 1])
X_test = pd.read_csv("X_test_filtered.csv", index_col=[0, 1])
y_train = pd.read_csv(r"C:\Users\earap\Documents\EBAC\DataScienceExcercises\Módulo 17 - Árvores II\ex026\UCI HAR Dataset\train\y_train.txt", header=None).squeeze("columns")
y_test = pd.read_csv(r"C:\Users\earap\Documents\EBAC\DataScienceExcercises\Módulo 17 - Árvores II\ex026\UCI HAR Dataset\test\y_test.txt", header=None).squeeze("columns")

# %%
clf = DecisionTreeClassifier(min_samples_leaf=20, random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(min_samples_leaf=20, random_state=42)

# %% [markdown]
# ### 2.2 Calcule os ccp_alphas. Como feito em aula, certifique-se de que todos os valores são positivos, e selecione apenas valores únicos.

# %%
path = clf.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas = path.ccp_alphas

# %%
ccp_alphas = np.unique(ccp_alphas[ccp_alphas > 0])

# %% [markdown]
# ### Passo 2.3: Selecionar um subconjunto de ccp_alphas (1 a cada 5 valores)

# %%
ccp_alphas_subset = ccp_alphas[::5]

# %%
print("Valores selecionados de ccp_alpha:", ccp_alphas_subset)
# Out:
# Valores selecionados de ccp_alpha: [6.96674540e-06 4.63397246e-05 6.73768888e-05 8.28222484e-05
#  1.02953015e-04 1.20580361e-04 1.41963138e-04 1.51968146e-04
#  1.67323005e-04 1.81439304e-04 1.96526409e-04 2.03119333e-04
#  2.05888258e-04 2.11960464e-04 2.26826797e-04 2.39444770e-04
#  2.47932477e-04 2.52885177e-04 2.62495937e-04 2.73408734e-04
#  2.83037295e-04 2.87980319e-04 3.13171720e-04 3.26787621e-04
#  3.51668945e-04 3.73564446e-04 3.99220300e-04 4.29862753e-04
#  4.51528412e-04 4.63079099e-04 4.87208882e-04 5.11794978e-04
#  5.25732429e-04 5.56286552e-04 6.37883381e-04 7.02050790e-04
#  7.53735819e-04 8.64950391e-04 9.29376560e-04 1.13240843e-03
#  1.24197638e-03 1.65230695e-03 2.18765587e-03 2.66788979e-03
#  3.13001880e-03 4.73006126e-03 1.05395082e-02]

# %% [markdown]
# ## 3. Desempenho da árvore por ccp_alpha
#
# - 3.1: Rode uma árvore para cada ```ccp_alpha```, salvando cada árvore em uma lista
# - 3.2: Calcule a acurácia de cada árvore na base de treinamento e de teste
# - 3.3: Monte um gráfico da acurácia em função do ```ccp_alpha``` na base de validação e na base de teste
# - 3.4: Selecione a melhor árvore como sendo aquela que possui melhor acurácia na base de teste
# - 3.5: Qual a melhor acurácia que se pode obter com estas três variáveis?
#
# **Dica:** utilize a estrutura do notebook apresentado em aula.
# **Dica 2:** meça o tempo com a função mágica ```%%time``` na primeira linha da célula.
# **Sugestão:** caso fique confortável com o tempo de execução, faça a busca pelo melhor ```ccp_alpha``` com mais iterações.
# **Sugestão 2:** caso fique confortável com o tempo de execução, tente inserir uma ou mais variáveis adicionais e veja se consegue aumentar a acurácia.

# %% [markdown]
# ### Passo 3.1: Treinar uma árvore para cada ccp_alpha

# %%
trees = []
train_acc = []
test_acc = []

# %%
for alpha in ccp_alphas_subset:
    tree = DecisionTreeClassifier(ccp_alpha=alpha, random_state=42)
    tree.fit(X_train, y_train)
    trees.append(tree)
    
    ### passo 3.2: calcular a Acurácia

    train_acc.append(accuracy_score(y_train, tree.predict(X_train)))
    test_acc.append(accuracy_score(y_test, tree.predict(X_test)))

# %% [markdown]
# ### Passo 3.3: Plotar a acurácia em função de ccp_alpha

# %%
plt.figure(figsize=(10, 5))
plt.plot(ccp_alphas_subset, train_acc, marker='o', label='Acurácia Treino')
plt.plot(ccp_alphas_subset, test_acc, marker='s', label='Acurácia Teste')
plt.xlabel("ccp_alpha")
plt.ylabel("Acurácia")
plt.xscale("log")
plt.legend()
plt.title("Acurácia em função do ccp_alpha")
plt.show()

# %% [markdown]
# ### Passo 3.4: Selecionar a melhor árvore (melhor acurácia na base de teste)

# %%
best_index = np.argmax(test_acc)
best_tree = trees[best_index]
best_alpha = ccp_alphas_subset[best_index]
best_accuracy = test_acc[best_index]

print(f"Melhor ccp_alpha: {best_alpha}")
print(f"Melhor acurácia na base de teste: {best_accuracy}")
# Out:
# Melhor ccp_alpha: 0.00037356444558905855
# Melhor acurácia na base de teste: 0.4468951476077367

# %% [markdown]
# ## Passo 4: Visualizar a árvore com melhor ccp_alpha

# %%
feature_names = X_train.columns.tolist()
class_names = [str(cls) for cls in np.unique(y_train)]

# %%
dot_data = export_graphviz(
    best_tree, out_file=None,
    feature_names=feature_names,
    class_names=class_names,
    filled=True, rounded=True,
    special_characters=True
)

# %%
graph = graphviz.Source(dot_data)
graph.render("best_decision_tree")  # Salva a árvore em um arquivo

graph.view()  # Abre a árvore renderizada
# Out:
# 'best_decision_tree.pdf'

# %%
# exibindo a árvore diretamente no notebook
display(graph)
