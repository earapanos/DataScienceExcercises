# %% [markdown]
# [![ebac_logo-data_science.png](https://raw.githubusercontent.com/earapanos/DataScienceExcercises/refs/heads/main/ebac_logo-data_science.png)](https://github.com/earapanos/DataScienceExcercises/tree/main)
# <!-- <img src="https://raw.githubusercontent.com/earapanos/DataScienceExcercises/refs/heads/main/ebac_logo-data_science.png" alt="ebac_logo-data_science"> -->
#
# ---
#
# <!-- # **Profissão: Cientista de Dados** -->
# ### **Módulo 26** | Algebra Linear | Exercício 1
#
# **Aluno:** [Eduardo Adriani Rapanos](https://www.linkedin.com/in/eduardo-rapanos/)<br>
# **Data:** 08 de abril de 2025.
#
# ---

# %% [markdown]
# # Tarefa - Álgebra Linear
#
# A célula abaixo gera dados de notas de duas provas, p1 e p2, conforme em aula, mas com mais alunos.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# Gerando os dados
np.random.seed(123)

p1 = np.random.random(50) *10
p1[p1>10] = 10
p1[p1<0] = 0

p2 = p1 + np.random.normal(0,1,50)
p2[p2>10] = 10
p2[p2<0] = 0

df = pd.DataFrame({'p1': p1, 'p2': p2})
df.head()
# Out:
#          p1        p2
# 0  6.964692  7.943428
# 1  2.861393  5.099537
# 2  2.268515  0.974429
# 3  5.513148  4.474359
# 4  7.194690  8.938402

# %% [markdown]
# ## 1. Reduzindo correlações
#
# a) Já vimos que expressar os dados através da média e diferença é uma transformação linear. Obtenha a média e a diferença através de uma multiplicação matricial, conforme visto em aula.

# %%
# Matriz de transformação
m = np.array([[.5,.5],   # Média
              [-1, 1]])  # Diferença

# Cálculo da média e diferença entre p1 e p2 através de multiplicação matricial
df['média'], df['diferença'] = np.matmul(m, df[['p1', 'p2']].to_numpy().transpose())

(df.style  # Configurar o estilo do dataframe
   .format(precision=2,  # Definir a precisão para 2 casas decimais
           decimal=',')
   .bar(subset='diferença',  # Estilização da coluna 'diferença' com barras coloridas para visualizar valores positivos e negativos
        color=['pink', 'lightblue'], 
        align='zero'))
# Out:
# <style type="text/css">
# #T_3dffe_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 71.9%, transparent 71.9%);
# }
# #T_3dffe_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# #T_3dffe_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 21.1%, pink 21.1%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.8%, pink 26.8%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 89.0%, transparent 89.0%);
# }
# #T_3dffe_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.2%, pink 32.2%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.7%, transparent 50.7%);
# }
# #T_3dffe_row7_col3, #T_3dffe_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 73.9%, transparent 73.9%);
# }
# #T_3dffe_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 69.9%, transparent 69.9%);
# }
# #T_3dffe_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 89.2%, transparent 89.2%);
# }
# #T_3dffe_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 83.4%, transparent 83.4%);
# }
# #T_3dffe_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.7%, pink 32.7%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 67.8%, transparent 67.8%);
# }
# #T_3dffe_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 57.0%, transparent 57.0%);
# }
# #T_3dffe_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, pink 20.4%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 81.7%, transparent 81.7%);
# }
# #T_3dffe_row17_col3, #T_3dffe_row35_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 68.0%, transparent 68.0%);
# }
# #T_3dffe_row18_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 51.0%, transparent 51.0%);
# }
# #T_3dffe_row19_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.8%, pink 44.8%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row20_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 23.2%, pink 23.2%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row21_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 54.5%, transparent 54.5%);
# }
# #T_3dffe_row22_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 60.5%, transparent 60.5%);
# }
# #T_3dffe_row23_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.4%, pink 31.4%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row24_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 76.0%, transparent 76.0%);
# }
# #T_3dffe_row25_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 25.5%, pink 25.5%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row26_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 2.6%, pink 2.6%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row27_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 73.2%, transparent 73.2%);
# }
# #T_3dffe_row28_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.0%, pink 41.0%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row29_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 47.2%, pink 47.2%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row30_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.3%, pink 31.3%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row31_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 14.1%, pink 14.1%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row32_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 78.0%, transparent 78.0%);
# }
# #T_3dffe_row33_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.6%, pink 34.6%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row34_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 87.1%, transparent 87.1%);
# }
# #T_3dffe_row36_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.0%, pink 43.0%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row37_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 25.7%, pink 25.7%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row38_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.6%, pink 33.6%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row39_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.9%, pink 22.9%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row40_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 96.6%, transparent 96.6%);
# }
# #T_3dffe_row41_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 53.7%, transparent 53.7%);
# }
# #T_3dffe_row42_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 75.7%, transparent 75.7%);
# }
# #T_3dffe_row43_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 21.7%, pink 21.7%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row44_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 54.0%, transparent 54.0%);
# }
# #T_3dffe_row45_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 76.3%, transparent 76.3%);
# }
# #T_3dffe_row46_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 42.5%, pink 42.5%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row47_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 53.2%, transparent 53.2%);
# }
# #T_3dffe_row48_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 25.8%, pink 25.8%, pink 50.0%, transparent 50.0%);
# }
# #T_3dffe_row49_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 19.5%, pink 19.5%, pink 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_3dffe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3dffe_level0_col0" class="col_heading level0 col0" >p1</th>
#       <th id="T_3dffe_level0_col1" class="col_heading level0 col1" >p2</th>
#       <th id="T_3dffe_level0_col2" class="col_heading level0 col2" >média</th>
#       <th id="T_3dffe_level0_col3" class="col_heading level0 col3" >diferença</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dffe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3dffe_row0_col0" class="data row0 col0" >6,96</td>
#       <td id="T_3dffe_row0_col1" class="data row0 col1" >7,94</td>
#       <td id="T_3dffe_row0_col2" class="data row0 col2" >7,45</td>
#       <td id="T_3dffe_row0_col3" class="data row0 col3" >0,98</td>
#     </tr>
#     <tr>
#       <th id="T_3dffe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3dffe_row1_col0" class="data row1 col0" >2,86</td>
#       <td id="T_3dffe_row1_col1" class="data row1 col1" >5,10</td>

# %%
# Definição da figura e configuração dos eixos
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

# Gráfico dos valores de p1 na horizontal X p2 na vertical
scatter1 = ax[0].scatter(x=df.p1, y=df.p2)
ax[0].set_xlabel('p1')  # Legenda do eixo x
ax[0].set_ylabel('p2')  # Legenda do eixo y

# Gráfico da Média em relação a Diferença de p1 X p2
scatter2 = ax[1].scatter(x=df['média'], y=df['diferença'])
ax[1].axhline(y=0, linewidth=0.5, linestyle='--')  # Linha horizontal no valor 0
ax[1].set_xlabel('Média')  # Legenda do eixo x
ax[1].set_ylabel('Diferença')  # Legenda do eixo y

plt.show()

# %% [markdown]
# b) Calcule a correlação entre os dados da **p1** e **p2**

# %%
print("Correlação entre p1 e p2:", df.p1.corr(df.p2))
# Out:
# Correlação entre p1 e p2: 0.8957365818728046

# %% [markdown]
# c) Calcule a correlação entre os dados transformados (média e diferença)

# %%
print("Correlação entre a média e a diferença:", df['média'].corr(df['diferença']))
# Out:
# Correlação entre a média e a diferença: 0.13347385411788837

# %% [markdown]
# d) Comente as correlações observadas.

# %% [markdown]
# Correlação entre os dados das variáveis p1 e p2:
#
# * A correlação de 0,89 demonstra uma forte correlação positiva entre as amostras das colunas p1 e p2. Isso significa que essas variáveis têm uma relação positiva, indicando uma forte associação e semelhança entre os dois conjuntos de dados.
# Correlação entre os dados transformados (média e diferença):
#
# * O valor resultante de -0,13 indica uma correlação negativa relativamente baixa entre as variáveis transformadas. Isso significa que há uma relação inversa, ou seja, à medida que uma variável aumenta, a outra tende a diminuir, e vice-versa. No entanto, o valor próximo de zero (-0,13) indica uma correlação inversa fraca. Essa relação inversa pode não ser tão significativa ou previsível.

# %% [markdown]
# ## 2. Soma e diferença
#
# Realize agora uma transformação semelhante, mas que ao invés da média, dê a soma da **p1** e **p2**. Construa o gráfico e conclua que diferenças visuais você observa.

# %%
df['soma'] = df.p1 + df.p2  # Cálculo da soma entre p1 e p2

(df.style  # Configurar o estilo do dataframe
   .format(precision=2,  # Definir a precisão para 2 casas decimais
           decimal=',')
   .bar(subset='diferença',  # Estilização da coluna 'diferença' com barras coloridas para visualizar valores positivos e negativos
        color=['pink', 'lightblue'], 
        align='zero')
   .background_gradient(subset=['média', 'soma']))
# Out:
# <style type="text/css">
# #T_192ca_row0_col2, #T_192ca_row0_col4 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_192ca_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 71.9%, transparent 71.9%);
# }
# #T_192ca_row1_col2, #T_192ca_row1_col4, #T_192ca_row12_col2, #T_192ca_row12_col4 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_192ca_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# #T_192ca_row2_col2, #T_192ca_row2_col4 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_192ca_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 21.1%, pink 21.1%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row3_col2, #T_192ca_row3_col4 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_192ca_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.8%, pink 26.8%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row4_col2, #T_192ca_row4_col4 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_192ca_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 89.0%, transparent 89.0%);
# }
# #T_192ca_row5_col2, #T_192ca_row5_col4 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_192ca_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.2%, pink 32.2%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row6_col2, #T_192ca_row6_col4 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_192ca_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.7%, transparent 50.7%);
# }
# #T_192ca_row7_col2, #T_192ca_row7_col4 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_192ca_row7_col3, #T_192ca_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 73.9%, transparent 73.9%);
# }
# #T_192ca_row8_col2, #T_192ca_row8_col4 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_192ca_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 69.9%, transparent 69.9%);
# }
# #T_192ca_row9_col2, #T_192ca_row9_col4 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_192ca_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 89.2%, transparent 89.2%);
# }
# #T_192ca_row10_col2, #T_192ca_row10_col4 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_192ca_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 83.4%, transparent 83.4%);
# }
# #T_192ca_row11_col2, #T_192ca_row11_col4, #T_192ca_row24_col2, #T_192ca_row24_col4 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_192ca_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.7%, pink 32.7%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row13_col2, #T_192ca_row13_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_192ca_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 67.8%, transparent 67.8%);
# }
# #T_192ca_row14_col2, #T_192ca_row14_col4 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_192ca_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 57.0%, transparent 57.0%);
# }
# #T_192ca_row15_col2, #T_192ca_row15_col4 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_192ca_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, pink 20.4%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row16_col2, #T_192ca_row16_col4, #T_192ca_row26_col2, #T_192ca_row26_col4 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_192ca_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 81.7%, transparent 81.7%);
# }
# #T_192ca_row17_col2, #T_192ca_row17_col4 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_192ca_row17_col3, #T_192ca_row35_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 68.0%, transparent 68.0%);
# }
# #T_192ca_row18_col2, #T_192ca_row18_col4 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_192ca_row18_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 51.0%, transparent 51.0%);
# }
# #T_192ca_row19_col2, #T_192ca_row19_col4 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_192ca_row19_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.8%, pink 44.8%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row20_col2, #T_192ca_row20_col4 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_192ca_row20_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 23.2%, pink 23.2%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row21_col2, #T_192ca_row21_col4 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_192ca_row21_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 54.5%, transparent 54.5%);
# }
# #T_192ca_row22_col2, #T_192ca_row22_col4 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_192ca_row22_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 60.5%, transparent 60.5%);
# }
# #T_192ca_row23_col2, #T_192ca_row23_col4 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_192ca_row23_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.4%, pink 31.4%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row24_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 76.0%, transparent 76.0%);
# }
# #T_192ca_row25_col2, #T_192ca_row25_col4 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_192ca_row25_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 25.5%, pink 25.5%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row26_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 2.6%, pink 2.6%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row27_col2, #T_192ca_row27_col4 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_192ca_row27_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 73.2%, transparent 73.2%);
# }
# #T_192ca_row28_col2, #T_192ca_row28_col4 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_192ca_row28_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.0%, pink 41.0%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row29_col2, #T_192ca_row29_col4 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_192ca_row29_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 47.2%, pink 47.2%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row30_col2, #T_192ca_row30_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_192ca_row30_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.3%, pink 31.3%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row31_col2, #T_192ca_row31_col4, #T_192ca_row35_col2, #T_192ca_row35_col4 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_192ca_row31_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 14.1%, pink 14.1%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row32_col2, #T_192ca_row32_col4 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_192ca_row32_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 78.0%, transparent 78.0%);
# }
# #T_192ca_row33_col2, #T_192ca_row33_col4 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_192ca_row33_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.6%, pink 34.6%, pink 50.0%, transparent 50.0%);
# }
# #T_192ca_row34_col2, #T_192ca_row34_col4 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_192ca_row34_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent

# %%
# Definição da figura e configuração dos eixos
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

# Gráfico dos valores de p1 na horizontal X p2 na vertical
scatter1 = ax[0].scatter(x=df.p1, y=df.p2, c=df['média'])
ax[0].set_xlabel('p1')  # Legenda do eixo x
ax[0].set_ylabel('p2')  # Legenda do eixo y

# Barra de cores para representar a média
cbar = fig.colorbar(scatter1, ax=ax[0])
cbar.set_label('Média')  # Legenda da barra de cores

# Gráfico da Soma em relação a Diferença de p1 X p2
scatter2 = ax[1].scatter(x=df['soma'], y=df['diferença'], c=df['média'])
ax[1].axhline(y=0, linewidth=0.5, linestyle='--')  # Linha horizontal no valor 0
ax[1].set_xlabel('Soma')  # Legenda do eixo x
ax[1].set_ylabel('Diferença')  # Legenda do eixo y

plt.show()

# %% [markdown]
# Ao analisar o primeiro gráfico, podemos observar uma distribuição proporcional entre todos os valores de 0 a 10 tanto na variável ```p1``` quanto na variável ```p2```. Isso significa que a distribuição dos pontos é equilibrada e não há concentração em uma faixa específica. Consequentemente, a média resultante também apresenta uma distribuição semelhante, refletindo as proporções das variáveis ```p1``` e ```p2```.
#
# Após a transformação dos dados para gerar a soma e a diferença, podemos perceber que a variação também é proporcional tanto no aumento quanto na diminuição dos valores de ```p1``` em relação a ```p2``` em todos os dados. Isso sugere que as operações de soma e diferença preservam a proporção entre os valores das variáveis, mantendo a relação entre elas.
#
# Essas observações indicam que as relações entre ```1p1``` e ```p2```, tanto na distribuição original quanto nas operações de soma e diferença, possuem uma característica de proporcionalidade e mantêm as proporções entre os valores, o que pode ser importante para a análise e interpretação dos dados. Além disso, podemos concluir que a soma das duas variáveis nada mais é do que o dobro da média, e que a média, por sua vez, é a metade da soma das duas variáveis. Essa relação adicional entre a soma, a média e as variáveis ```p1``` e ```p2``` reforça ainda mais a importância da proporção na análise dos dados.
